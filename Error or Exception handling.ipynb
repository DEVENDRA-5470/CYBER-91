# %%
# 1.Error or Exception handling.
num=40
div=0
res=num/div
print(res)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 num=40
#       3 div=0
# ----> 4 res=num/div
#       5 print(res)
#
# ZeroDivisionError: division by zero

# %%
try:
    num=40
    div="5"
    res=num/dev
    print(res)
except ZeroDivisionError:
    print("Please enter valid number")
except TypeError:
    print("Please enter valid data..")
except NameError:
    print("Please enter valid varible..")
finally:
    print("Thanks for visiting...")
# Out:
# Please enter valid varible..
# Thanks for visiting...

# %%
try:
    num=40
    div="erew"
    res=num/div
    print(res)
except Exception as e:
    print("Error:",e)
finally:
    print("Thanks for visiting...")
# Out:
# Error: unsupported operand type(s) for /: 'int' and 'str'
# Thanks for visiting...
