# %%
# Types of modules.
# 1.User-define module 
# 2.In-built module.

# %%
from dev import check_odd_even

# %%
check_odd_even(16)
# Out:
# 'Even'

# %%
import random
random_num=random.random()*10000
print(int(random_num))
# Out:
# 677

# %%
random_num=random.randint(100,500) # includes both point
print(random_num)
# Out:
# 264

# %%
random_num=random.randrange(10,15) # includes first point
print(random_num)
# Out:
# 12

# %%
random_num=random.choice(["aman","kamal","ajay"])
print(random_num)
# Out:
# ajay

# %%
random_num=random.choices(["aman","kamal","ajay"],weights=[0,2,1],k=6)
print(random_num)
# Out:
# ['kamal', 'kamal', 'kamal', 'kamal', 'kamal', 'ajay']

# %%
data=["aman","kamal","ajay"]
random.shuffle(data)
print(data)
# Out:
# ['kamal', 'aman', 'ajay']

# %%
data=["aman","kamal","ajay"]
res=random.sample(data,k=3)
print(res)
# Out:
# ['kamal', 'aman', 'ajay']

# %%
import string

# %%
abc=string.ascii_lowercase
print(abc)
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
abc=string.ascii_uppercase
print(abc)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
abc=string.ascii_letters
print(abc)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
abc=string.digits
print(abc)
# Out:
# 0123456789

# %%
abc=string.hexdigits
print(abc)
# Out:
# 0123456789abcdefABCDEF

# %%
emp_id=[random.choice(string.digits) for i in range(10)]
print(emp_id)
# Out:
# ['7', '8', '7', '0', '6', '4', '0', '3', '0', '1']

# %%
winning_point=500
user_attempt=6
randrange(100,500)

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', '1nov-variables.ipynb', '4-nov-operators.ipynb', 'Data-structure collections.ipynb', 'Dictionary.ipynb', 'Error or Exception handling.ipynb', 'LINUX-NOTES', 'list.ipynb', 'loops_in_python.ipynb', 'Modules or libraries.ipynb', 'sets.ipynb', 'Untitled.ipynb']

# %%
print(os.getcwd())
# Out:
# C:\Users\dev\BATCH-91-2025

# %%
os.chdir(r"C:\Users\dev")

# %%
print(os.getcwd())
# Out:
# C:\Users\dev

# %%
data=os.listdir()
for i in data:
    if "Down" in i:
        print(i)
# Out:
# Downloads

# %%
os.chdir(r"C:\Users\dev\Downloads")

# %%
os.mkdir("Dummy")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dev\\Downloads'

# %%
os.chdir(r"C:\Users\dev\BATCH-91-2025\Dummy")

# %%
print(os.listdir())
# Out:
# []

# %%
res=os.path.expanduser("~")
print(res)
# Out:
# C:\Users\dev

# %%
os.chdir(os.path.expanduser("~"))

# %%
print(os.getcwd())
# Out:
# C:\Users\dev

# %%
print(os.path.exists(r"C:\Users\dev\BATCH-91-2025\python"))
# Out:
# False

# %%
path=r"C:\Users\dev\BATCH-91-2025\testing"
if os.path.exists(path):
    print("yes")
else:
    os.mkdir(path)
    print("Created...")
# Out:
# yes

# %%
st=os.stat(r"C:\Users\dev\BATCH-91-2025\testing")
print(st)
# Out:
# os.stat_result(st_mode=16895, st_ino=1970324837272000, st_dev=15015074293971317104, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1764823258, st_mtime=1764823258, st_ctime=1764823258)

# %%
os.chdir(r"C:\Users\dev\BATCH-91-2025")
data=os.listdir()
# print(data)
file=open("cred.txt","w")
for i in data:
    print(i)
    file.writelines(i+"\n")
file.close()
print("File created")
# Out:
# .git
# .ipynb_checkpoints
# 1nov-variables.ipynb
# 4-nov-operators.ipynb
# cred.txt
# Data-structure collections.ipynb
# Dictionary.ipynb
# Dummy
# Error or Exception handling.ipynb
# LINUX-NOTES
# list.ipynb
# loops_in_python.ipynb
# Modules or libraries.ipynb
# python
# sets.ipynb
# testing
# Untitled.ipynb
# File created

# %%
print(os.getcwd())
# Out:
# C:\Users\dev
