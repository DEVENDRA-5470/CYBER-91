# %%
l=["aman", "shivam", "raju"]
new_list=['x' for x in l if x=="a"]
print(new_list)
# Out:
# []

# %%
#7. Write a program to find out palindromes from a list of words. ["madam",
l=["madam", "racecar", "python", "level", "hello"]
new_list=["x" for x in l if x==l.sort(reverse=True)]
print(new_list)
# Out:
# []

# %%
l=[35, 80, 50, 39, 90]
new_list=["80%" for x in l if x>=40 ]
print(new_list)
# Out:
# ['80%', '80%', '80%']

# %%
l=["apple", "banana", "cherry", "dog", "elephant"]
new_list=
for x in l:
print()
# Out:
#   Cell In[4], line 2
#     new_list=
#              ^
# SyntaxError: invalid syntax
