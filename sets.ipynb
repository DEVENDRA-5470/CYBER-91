# %%
#---------------------------------- Set -------------------
# 1.Defination and properites
# 2.Creation
# 3.update/modification 
# 4.slicing ❌
# 5.Traversing 
# 6.built-in methods.
# 7.Assignemnts+practices

# %%
# 1.Defination and properites
# 1.Set is a data structure use to store unique data.
# 2.Set does not support duplicat values.
# 3.Set does not support indexing and ordered.
# 4.Set can define by using set() method and {}.
# 5.Set is mutable.

# %%
# 2.Creation
set1={1,2,3,5,3,2,3}
print(set1)
# Out:
# {1, 2, 3, 5}

# %%
# 2.Creation
set1=set([5,6,78,5,4,3,3])
print(set1)
# Out:
# {3, 4, 5, 6, 78}

# %%
# 3.update/modification 
set1={1,2,3,5,3,2,3}
set1.add(90)
set1.add("dv")
print(set1)
# Out:
# {1, 2, 3, 5, 'dv', 90}

# %%
s1={1,23,4,5,5}
s2={"a","c","x","y"}
s1.update(s2)
print(s1)
# Out:
# {1, 'c', 4, 5, 'x', 'y', 'a', 23}

# %%
# 5.Traversing 
# set1={1,2,3,5,3,2,3}
# for i in range(len(set1)):
#     print(i)

# set1={1,2,3,5,3,2,3}
# for i in set1:
#     print(i)

set1={1,2,3,5,3,2,3}
ls=list(set1)
i=0
while i<len(ls):
    print(ls[i])
    i=i+1
else:
    print("ok")
# Out:
# 1
# 2
# 3
# 5
# ok

# %%
set1={1,2,3,5,3,2,3}
ls=list(set1)
print(ls)
print(set1)
# Out:
#   Cell In[19], line 5
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
# 6.built-in methods.
set1={1,2,3,5,3,2,3}
